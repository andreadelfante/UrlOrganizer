# %%
from utils.RunSkipgramExperiments import RunSkipgramExperiments

# %matplotlib inline

# %%
direct = "/Volumes/AdditionalDriveMAC/Google Drive/1) Tesi/Sperimentazioni/" \
         "cs.priceton.edu/" \
         "ListConstraint/" \
         "cs.priceton.edu.ListConstraint.words1000000.depth20.window7.iteractions3/"
scaling = "l2"
separator = "\t"

intersect = True

# %%
experiment = RunSkipgramExperiments(direct=direct, scale=scaling, separator=separator, intersect=intersect)
# Out:
# scaling embeddings with L2 normalization
# scaling embeddings with L2 normalization
# scaling embeddings with L2 normalization
# Original urls: 3132
# Intersected urls: 2813
# Original urls: 2813
# Intersected urls: 2813
# Original urls: 2813
# Intersected urls: 2813
# Start running KMeans
# Start running KMeans
# Start running KMeans
# Start running HDBscan
# Start running HDBscan
# Start running HDBscan
# Homogeneity: 0.496114293909
# Completeness: 0.361085157056
# V-Measure core: 0.41796458813
# Adjusted Rand index: 0.2646018232447431
# Mutual Information: 0.350250083742
# Silhouette: 0.114996631111
# Homogeneity: 0.456293869186
# Completeness: 0.324024319265
# V-Measure core: 0.37894877381
# Adjusted Rand index: 0.32015993879101645
# Mutual Information: 0.312774584405
# Silhouette: 0.0142026053307
# Homogeneity: 0.65790113712
# Completeness: 0.467282469976
# V-Measure core: 0.546445338192
# Adjusted Rand index: 0.41138852694637
# Mutual Information: 0.458398007422
# Silhouette: 0.104711112145
# Homogeneity: 0.290330298542
# Completeness: 0.264654840365
# V-Measure core: 0.276898653413
# Adjusted Rand index: 0.11292770983053828
# Mutual Information: 0.226988026924
# Silhouette: -0.0232196688946
# Homogeneity: 0.299185559273
# Completeness: 0.481212449426
# V-Measure core: 0.36897022854
# Adjusted Rand index: 0.28748311679494964
# Mutual Information: 0.284729704355
# Silhouette: 0.075704526944
# Homogeneity: 0.503053171197
# Completeness: 0.360815378805
# V-Measure core: 0.420224397622
# Adjusted Rand index: 0.26710106007464385
# Mutual Information: 0.32022240239
# Silhouette: 0.070113926854

# %%
print("Metrics WITH B VALUE")

experiment.get_dataframe_with_b()
# Out:
# Metrics WITH B VALUE
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Adj Mutual info</th>
#       <th>Adj Rand index</th>
#       <th>Completeness</th>
#       <th>Homogeneity</th>
#       <th>Silhouette</th>
#       <th>V-Measure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>KMeans</th>
#       <td>0.35</td>
#       <td>0.26</td>
#       <td>0.36</td>
#       <td>0.50</td>
#       <td>0.11</td>
#       <td>0.42</td>
#     </tr>
#     <tr>
#       <th>HDBScan</th>
#       <td>0.23</td>
#       <td>0.11</td>
#       <td>0.26</td>
#       <td>0.29</td>
#       <td>-0.02</td>
#       <td>0.28</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print("Metrics WITHOUT B VALUE")

experiment.get_dataframe_no_b()
# Out:
# Metrics WITHOUT B VALUE
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Adj Mutual info</th>
#       <th>Adj Rand index</th>
#       <th>Completeness</th>
#       <th>Homogeneity</th>
#       <th>Silhouette</th>
#       <th>V-Measure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>KMeans</th>
#       <td>0.31</td>
#       <td>0.32</td>
#       <td>0.32</td>
#       <td>0.46</td>
#       <td>0.01</td>
#       <td>0.38</td>
#     </tr>
#     <tr>
#       <th>HDBScan</th>
#       <td>0.28</td>
#       <td>0.29</td>
#       <td>0.48</td>
#       <td>0.30</td>
#       <td>0.08</td>
#       <td>0.37</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print("Metrics NORMAL")

experiment.get_dataframe_normal()
# Out:
# Metrics NORMAL
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Adj Mutual info</th>
#       <th>Adj Rand index</th>
#       <th>Completeness</th>
#       <th>Homogeneity</th>
#       <th>Silhouette</th>
#       <th>V-Measure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>KMeans</th>
#       <td>0.46</td>
#       <td>0.41</td>
#       <td>0.47</td>
#       <td>0.66</td>
#       <td>0.10</td>
#       <td>0.55</td>
#     </tr>
#     <tr>
#       <th>HDBScan</th>
#       <td>0.32</td>
#       <td>0.27</td>
#       <td>0.36</td>
#       <td>0.50</td>
#       <td>0.07</td>
#       <td>0.42</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print("Plotting normalized embeddings WITH B VALUE...")

experiment.plot_normalized_data_with_b(file_name=direct + "normalized_data_with_b_intersect")
# Out:
# Plotting normalized embeddings WITH B VALUE...
# <module 'matplotlib.pyplot' from '/Users/Andrea/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/pyplot.py'>

# %%
print("Plotting normalized embeddings WITHOUT B VALUE...")

experiment.plot_normalized_data_no_b(file_name=direct + "normalized_data_no_b_intersect")
# Out:
# Plotting normalized embeddings WITHOUT B VALUE...
# <module 'matplotlib.pyplot' from '/Users/Andrea/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/pyplot.py'>

# %%
print("Plotting normalized embeddings NORMAL SKIPGRAM...")

experiment.plot_normalized_data_normal(file_name=direct + "normalized_data_normal_intersect")
# Out:
# Plotting normalized embeddings NORMAL SKIPGRAM...
# <module 'matplotlib.pyplot' from '/Users/Andrea/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/pyplot.py'>
